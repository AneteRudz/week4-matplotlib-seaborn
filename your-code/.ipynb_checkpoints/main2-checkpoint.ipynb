# %% [markdown]
# # Solution lab matplotlib-seaborn

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Data

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
# There are 2 ways of doing this. Do in both ways.
# Hint: Check out the nrows, ncols, and index arguments of subplots
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way

'''
L.S. Correct!
'''

fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y, color = 'g', lw = 3)
ax2.plot(x,z, color = 'm', lw = 3)

plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot below

# %%
# your code here-2nd way


'''
L.S. Very good!
'''
plt.subplot(1,2,1)
plt.plot(x,y, color = 'c', lw = 3, ls = ':')

plt.subplot(1,2,2)
plt.plot(x,z, color = 'b', lw = 3, ls = '-.')

plt.show()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
# Hint: Add the figsize argument in plt.subplots()

# %%
#Your code here

fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15, 5))
ax1.plot(x,y, color = 'c')
ax2.plot(x,z, color = 'c')

plt.show()

# %% [markdown]
# #### Plot both y=x^2 and y=exp(x) in the same plot using normal and logarithmic scale.
# Hint: Use set_xscale and set_yscale

# %%
#your code here


'''
L.S. Correct, but the scale of the first subplot is a bit off.
'''

fig, [ax1, ax2] = plt.subplots(1, 2, figsize = (15,5))

ax1.plot(x, x**2, x, np.exp(x))
ax2.plot(x, x**2, x, np.exp(x))
plt.yscale('log')

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Import the Fitbit2.csv file and name your dataset fitbit

# %%
#Your code here

fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# 5    2015-05-13             276    779      5.79      15            726.000
# 6    2015-05-14            2687   5614      4.17       2            782.000
# 7    2015-05-15            2793   8169      6.07      14            801.000
# 8    2015-05-16            4061  19971     14.84      18            532.000
# 9    2015-05-17            3349    852      6.33      12            606.000
# 10   2015-05-18            2961  11998      8.91      20            936.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?
# Is Fitbitter more active on weekend or workdays?
# All plots must be in the same jupyter notebook cell.
# Hints:
#
# Use Months_encoded and Week_or Weekend columns
# Use matplolib.pyplot object oriented API
# Set your size figure to 12,4
# Explore plt.sca
# Explore plt.xticks
# Save your figures

# %%
# Median Steps by Month_encoded


'''
L.S. Correct!
'''

steps = fitbit.groupby('Months_encoded').agg({'Steps': ['median']})
by_month = pd.DataFrame(steps)
ax1 = by_month['Steps'].plot.bar()
ax1.set_xlabel('Months')
ax1.set_ylabel('Steps')
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=0)

# Median Steps by Work_or_Weekend

steps2 = fitbit.groupby('Work_or_Weekend').agg({'Steps': ['median']})
by_week = pd.DataFrame(steps2)

ax2 = by_week['Steps'].plot.bar()
ax2.set_xlabel('Workday vs Weekend')
ax2.set_ylabel('Steps')
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=0)
# Out:
# [Text(0,0,'0'), Text(0,0,'1')]

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# Minutes Lightly Active vs Steps
# Minutes Very Active vs Steps
# Minutes Sedentary vs Steps

# %%
#Your code here

'''
L.S. Does not seem to work. 
'''

x = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
y = ['Steps']

for i in x:
    ax = sns.scatterplot(y = y[0], x = i, data=fitbit, legend='brief')
    ax.set_ylabel('Steps')
    ax.set_xlabel('Activity')
    ax.legend(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-512d4b14fdc5> in <module>()
#       9
#      10 for i in x:
# ---> 11     ax = sns.scatterplot(y = y[0], x = i, data=fitbit, legend='brief')
#      12     ax.set_ylabel('Steps')
#      13     ax.set_xlabel('Activity')
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the titanic file. Name your dataset titanic

# %%
# your code here
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# Hint: Use Pandas select_dtypes

# %%
#your code here

titanic.select_dtypes(np.number).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here

titanic.select_dtypes(object).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6)
# Hint: To set the style you can use matplotlib.pyplot functions or seaborn

# %%
# your code here

plt.style.use('classic')
plt.rcParams['figure.figsize'] = [12.0, 6.0]

# %% [markdown]
# #### Use the right visulalization to show the distribution of the column Age

# %%
# your code here


'''
L.S. Correct!
'''

titanic['Age'].hist()

# %% [markdown]
# #### Use subplots and plot the distribution of the Age variable with bins equal to 10,20 and 50.

# %%
# your code here


'''
L.S. Well done!
'''

plt.subplot(1,3,1)
titanic['Age'].hist(bins = 10)

plt.subplot(1,3,2)
titanic['Age'].hist(bins = 20)

plt.subplot(1,3,3)
titanic['Age'].hist(bins = 50)


plt.show()

# %% [markdown]
# #### How does the bin size affect your plot? Comment.

# %%
#your comment here

# The bigger the bin size, the fewer bins are needed.

# %% [markdown]
# #### Use seaborn to show the distribution of the column Age

# %%
# your code here


'''
L.S. Nice!
'''

sns.distplot(titanic['Age'], bins=20)

# %% [markdown]
# #### Use the right plot to visualize the column Gender. There are 2 ways of doing it. Do it both ways.
# Hint: Use matplotlib and seaborn

# %%
# your code here- 1st way



'''
L.S. Good!
'''
sns.catplot(x='Gender', kind='count', data = titanic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-30e4a4c9d8f5> in <module>()
#       1 # your code here- 1st way
#       2
# ----> 3 sns.catplot(x='Gender', kind='count', data = titanic)
#
# AttributeError: module 'seaborn' has no attribute 'catplot'

# %%
# your code here- 2nd way

titanic['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# #### Use the right plot to visualize the column Pclass

# %%
# your code here


sns.catplot(x='Pclass', kind='count', data = titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature Age. What kind of plot would you use?

# %%
#Your code here



'''
L.S. Correct!
'''
sns.boxplot(titanic['Age'], linewidth=2.5, color = 'g')

# %% [markdown]
# #### What does the last plot tells you about the feature Age? Comment.

# %%
# your comment here

# 50% of passengers were around 28 years old.
# 25% of passengers were younger than 22 and 75% were younger than 37.
# Only a few passengers were older than 60 years old.
# The oldest passenger was 80 years old.

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the SAME plot the distribution of Age. What kind of plot would you use?

# %%
#your code here


'''
L.S. Correct!
'''

plt.hist(titanic['Age'], color = 'g', bins = 20)
plt.figtext(0.7,0.6, titanic['Age'].describe().to_string())
# Out:
# Text(0.7, 0.6, 'count    1309.000000\nmean       29.879186\nstd        13.448335\nmin         0.170000\n25%        22.000000\n50%        28.500000\n75%        37.000000\nmax        80.000000')

# %% [markdown]
# #### What additional information the last plot provides you about the feature Age? Comment.

# %%
#your comment here

# This plot shows how many passengers are in each age bin.

# %% [markdown]
# #### We suspect that there is a linear relationship between Fare and Age. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# Hint: One of the ways involves using Seaborn

# %%
#your code- 1st way


'''
L.S. Nice, well done!
'''


sns.regplot(x = 'Age', y = 'Fare', data = titanic)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(titanic['Age'], titanic['Fare'])

# %%
plt.plot(titanic['Age'], titanic['Fare'], 'o', label='original')
plt.plot(titanic['Age'], intercept + slope*titanic['Age'], r_value, label='fitted')
plt.legend()
plt.show()

# %% [markdown]
# #### Using Seaborn plot the correlation matrix

# %%
corr = titanic.corr()

# %%
'''
L.S. Very good!
'''

# mask the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# set up the matplotlib figure
f, ax = plt.subplots(figsize=(12,6))

# set up a custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap
ax1 = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, 
                  linewidths=.5, cbar_kws={'shrink':.5}).set_title('Correlation Matrix')

# %% [markdown]
# #### What are the most correlated feature? Comment

# %%
# The strongest positive correlation is between Parch and SibSp features (r = 0.37)
# The strongest negative correlation is between Fare and Pclass features (r = -0.45)

# %% [markdown]
# #### Use the right plot to display the summary statistics of the Age in function of the Pclass

# %%
#your code here

sns.boxplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use the seaborn to plot the distribution of the Age based on the Gender
# Hint: Use Facetgrid

# %%
#your code here

g = sns.FacetGrid(titanic, col = 'Gender')
g.map(plt.hist, 'Age')
